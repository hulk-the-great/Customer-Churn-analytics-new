# %%
import pandas as pd

df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
df.describe(include="all")
df["Churn"].value_counts()
df.groupby("Contract")["Churn"].value_counts(normalize=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.shape
df.columns.tolist()
df.info()
df.isnull().sum()
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.shape
#       2 df.columns.tolist()
#       3 df.info()
#       4 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df.shape
df.columns.tolist()
df.info()
df.isnull().sum()
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.shape
#       2 df.columns.tolist()
#       3 df.info()
#       4 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
df.columns.tolist()
df.info()
df.isnull().sum()
df.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["TotalCharges"].head(10)
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# 5      820.5
# 6     1949.4
# 7      301.9
# 8    3046.05
# 9    3487.95
# Name: TotalCharges, dtype: str

# %%
df.shape
df.columns.tolist()
df.info()
df.isnull().sum()
df.duplicated().sum()
df["TotalCharges"].head(10)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
(df["TotalCharges"] == " ").sum()
# Out:
# np.int64(11)

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df = df.dropna(subset=["TotalCharges"]).copy()

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (7032, 21)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].str.strip()
# Out:
# C:\Users\vijyadla\AppData\Local\Temp\ipykernel_32104\1126013313.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include="object").columns:

# %%
for col in df.select_dtypes(include=["object", "string"]).columns:
    df[col] = df[col].str.strip()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   str
#  1   gender            7032 non-null   str
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   str
#  4   Dependents        7032 non-null   str
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   str
#  7   MultipleLines     7032 non-null   str
#  8   InternetService   7032 non-null   str
#  9   OnlineSecurity    7032 non-null   str
#  10  OnlineBackup      7032 non-null   str
#  11  DeviceProtection  7032 non-null   str
#  12  TechSupport       7032 non-null   str
#  13  StreamingTV       7032 non-null   str
#  14  StreamingMovies   7032 non-null   str
#  15  Contract          7032 non-null   str
#  16  PaperlessBilling  7032 non-null   str
# ...

# %%
df.to_csv("../data/processed/churn_cleaned.csv", index=False)
print("Saved cleaned file")
# Out:
# Saved cleaned file

# %%
(df["TotalCharges"] == " ").sum()
df["TotalCharges"].isnull().sum()
df.shape
df.duplicated().sum()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   str
#  1   gender            7032 non-null   str
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   str
#  4   Dependents        7032 non-null   str
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   str
#  7   MultipleLines     7032 non-null   str
#  8   InternetService   7032 non-null   str
#  9   OnlineSecurity    7032 non-null   str
#  10  OnlineBackup      7032 non-null   str
#  11  DeviceProtection  7032 non-null   str
#  12  TechSupport       7032 non-null   str
#  13  StreamingTV       7032 non-null   str
#  14  StreamingMovies   7032 non-null   str
#  15  Contract          7032 non-null   str
#  16  PaperlessBilling  7032 non-null   str
# ...

# %%
quality_report = pd.DataFrame({
    "column": df.columns,
    "dtype": df.dtypes.astype(str).values,
    "missing_values": df.isnull().sum().values,
    "non_null_count": df.notnull().sum().values,
    "unique_values": [df[col].nunique() for col in df.columns]
})

quality_report
# Out:
#               column    dtype  missing_values  non_null_count  unique_values
# 0         customerID      str               0            7032           7032
# 1             gender      str               0            7032              2
# 2      SeniorCitizen    int64               0            7032              2
# 3            Partner      str               0            7032              2
# 4         Dependents      str               0            7032              2
# 5             tenure    int64               0            7032             72
# 6       PhoneService      str               0            7032              2
# 7      MultipleLines      str               0            7032              3
# 8    InternetService      str               0            7032              3
# 9     OnlineSecurity      str               0            7032              3
# 10      OnlineBackup      str               0            7032              3
# ...

# %%
rows_before = 7043
rows_after = len(df)
rows_removed = rows_before - rows_after
duplicate_rows = df.duplicated().sum()

summary_stats = pd.DataFrame({
    "metric": [
        "rows_before_cleaning",
        "rows_after_cleaning",
        "rows_removed",
        "duplicate_rows_after_cleaning"
    ],
    "value": [
        rows_before,
        rows_after,
        rows_removed,
        duplicate_rows
    ]
})

summary_stats
# Out:
#                           metric  value
# 0           rows_before_cleaning   7043
# 1            rows_after_cleaning   7032
# 2                   rows_removed     11
# 3  duplicate_rows_after_cleaning      0

# %%
quality_report.to_csv("../data/quality/data_quality_report.csv", index=False)
summary_stats.to_csv("../data/quality/data_quality_summary.csv", index=False)

print("Saved quality report files")
# Out:
# Saved quality report files

# %%
import os
os.makedirs("../data/quality", exist_ok=True)

# %%
import os

os.makedirs("../data/quality", exist_ok=True)

quality_report.to_csv("../data/quality/data_quality_report.csv", index=False)
summary_stats.to_csv("../data/quality/data_quality_summary.csv", index=False)

print("Saved quality report files")
# Out:
# Saved quality report files

# %%
summary_stats
# Out:
#                           metric  value
# 0           rows_before_cleaning   7043
# 1            rows_after_cleaning   7032
# 2                   rows_removed     11
# 3  duplicate_rows_after_cleaning      0

# %%
customers = df[
    [
        "customerID",
        "gender",
        "SeniorCitizen",
        "Partner",
        "Dependents",
        "tenure"
    ]
].copy()

customers.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure
# 0  7590-VHVEG  Female              0     Yes         No       1
# 1  5575-GNVDE    Male              0      No         No      34
# 2  3668-QPYBK    Male              0      No         No       2
# 3  7795-CFOCW    Male              0      No         No      45
# 4  9237-HQITU  Female              0      No         No       2

# %%
services = df[
    [
        "customerID",
        "PhoneService",
        "MultipleLines",
        "InternetService",
        "OnlineSecurity",
        "OnlineBackup",
        "DeviceProtection",
        "TechSupport",
        "StreamingTV",
        "StreamingMovies"
    ]
].copy()

services.head()
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No

# %%
billing = df[
    [
        "customerID",
        "Contract",
        "PaperlessBilling",
        "PaymentMethod",
        "MonthlyCharges",
        "TotalCharges"
    ]
].copy()

billing.head()
# Out:
#    customerID        Contract PaperlessBilling              PaymentMethod  \
# 0  7590-VHVEG  Month-to-month              Yes           Electronic check
# 1  5575-GNVDE        One year               No               Mailed check
# 2  3668-QPYBK  Month-to-month              Yes               Mailed check
# 3  7795-CFOCW        One year               No  Bank transfer (automatic)
# 4  9237-HQITU  Month-to-month              Yes           Electronic check
#
#    MonthlyCharges  TotalCharges
# 0           29.85         29.85
# 1           56.95       1889.50
# 2           53.85        108.15
# 3           42.30       1840.75
# 4           70.70        151.65

# %%
status = df[
    [
        "customerID",
        "Churn"
    ]
].copy()

status.head()
# Out:
#    customerID Churn
# 0  7590-VHVEG    No
# 1  5575-GNVDE    No
# 2  3668-QPYBK   Yes
# 3  7795-CFOCW    No
# 4  9237-HQITU   Yes

# %%
print("customers shape:", customers.shape)
print("services shape:", services.shape)
print("billing shape:", billing.shape)
print("status shape:", status.shape)
# Out:
# customers shape: (7032, 6)
# services shape: (7032, 10)
# billing shape: (7032, 6)
# status shape: (7032, 2)

# %%
import os
os.makedirs("../data/processed/tables", exist_ok=True)

# %%
customers.to_csv("../data/processed/tables/customers.csv", index=False)
services.to_csv("../data/processed/tables/services.csv", index=False)
billing.to_csv("../data/processed/tables/billing.csv", index=False)
status.to_csv("../data/processed/tables/status.csv", index=False)

print("Saved all split tables")
# Out:
# Saved all split tables

# %%
import os

print(os.path.exists("../data/processed/tables/customers.csv"))
print(os.path.exists("../data/processed/tables/services.csv"))
print(os.path.exists("../data/processed/tables/billing.csv"))
print(os.path.exists("../data/processed/tables/status.csv"))
# Out:
# True
# True
# True
# True

# %%
import sqlite3

conn = sqlite3.connect("../data/processed/churn_analytics.db")

customers.to_sql("customers", conn, if_exists="replace", index=False)
services.to_sql("services", conn, if_exists="replace", index=False)
billing.to_sql("billing", conn, if_exists="replace", index=False)
status.to_sql("status", conn, if_exists="replace", index=False)

print("Loaded all tables into SQLite")
# Out:
# Loaded all tables into SQLite

# %%
query = """
SELECT name
FROM sqlite_master
WHERE type='table';
"""

import pandas as pd
pd.read_sql(query, conn)
# Out:
#         name
# 0  customers
# 1   services
# 2    billing
# 3     status

# %%
test_query = """
SELECT c.customerID, c.gender, c.tenure, b.Contract, b.MonthlyCharges, s.Churn
FROM customers c
JOIN billing b ON c.customerID = b.customerID
JOIN status s ON c.customerID = s.customerID
LIMIT 5;
"""

pd.read_sql(test_query, conn)
# Out:
#    customerID  gender  tenure        Contract  MonthlyCharges Churn
# 0  7590-VHVEG  Female       1  Month-to-month           29.85    No
# 1  5575-GNVDE    Male      34        One year           56.95    No
# 2  3668-QPYBK    Male       2  Month-to-month           53.85   Yes
# 3  7795-CFOCW    Male      45        One year           42.30    No
# 4  9237-HQITU  Female       2  Month-to-month           70.70   Yes

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../data/processed/churn_analytics.db")
print("Connected")
# Out:
# Connected

# %%
query = """
SELECT
    COUNT(*) AS total_customers,
    SUM(CASE WHEN Churn = 'Yes' THEN 1 ELSE 0 END) AS churned_customers,
    ROUND(
        100.0 * SUM(CASE WHEN Churn = 'Yes' THEN 1 ELSE 0 END) / COUNT(*),
        2
    ) AS churn_rate_pct
FROM status;
"""

pd.read_sql(query, conn)
# Out:
#    total_customers  churned_customers  churn_rate_pct
# 0             7032               1869           26.58

# %%
query = """
SELECT
    b.Contract,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN s.Churn = 'Yes' THEN 1 ELSE 0 END) AS churned_customers,
    ROUND(
        100.0 * SUM(CASE WHEN s.Churn = 'Yes' THEN 1 ELSE 0 END) / COUNT(*),
        2
    ) AS churn_rate_pct
FROM billing b
JOIN status s
    ON b.customerID = s.customerID
GROUP BY b.Contract
ORDER BY churn_rate_pct DESC;
"""

pd.read_sql(query, conn)
# Out:
#          Contract  total_customers  churned_customers  churn_rate_pct
# 0  Month-to-month             3875               1655           42.71
# 1        One year             1472                166           11.28
# 2        Two year             1685                 48            2.85

# %%
query = """
SELECT
    b.PaymentMethod,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN s.Churn = 'Yes' THEN 1 ELSE 0 END) AS churned_customers,
    ROUND(
        100.0 * SUM(CASE WHEN s.Churn = 'Yes' THEN 1 ELSE 0 END) / COUNT(*),
        2
    ) AS churn_rate_pct
FROM billing b
JOIN status s
    ON b.customerID = s.customerID
GROUP BY b.PaymentMethod
ORDER BY churn_rate_pct DESC;
"""

pd.read_sql(query, conn)
# Out:
#                PaymentMethod  total_customers  churned_customers  \
# 0           Electronic check             2365               1071
# 1               Mailed check             1604                308
# 2  Bank transfer (automatic)             1542                258
# 3    Credit card (automatic)             1521                232
#
#    churn_rate_pct
# 0           45.29
# 1           19.20
# 2           16.73
# 3           15.25
